# %% [markdown]
# <a href="https://colab.research.google.com/github/SriPorwal/PythonProjects/blob/main/numpy_crash_course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to the Numpy crash course!")
# Out:
# Welcome to the Numpy crash course!

# %%
import numpy as np

# %%
a1 = np.array([4,5,6,7])

# %%
a1
# Out:
# array([4, 5, 6, 7])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a2 = np.array([[1,2,3], [6,5,4]])

# %%
a2
# Out:
# array([[1, 2, 3],
#        [6, 5, 4]])

# %%
type(a2)
# Out:
# numpy.ndarray

# %%
a2 = np.array([[1,2,3], [6,5,4]], dtype = float)
a2
# Out:
# array([[1., 2., 3.],
#        [6., 5., 4.]])

# %%
a4 = np.arange(5)
a4
# Out:
# array([0, 1, 2, 3, 4])

# %%
a5 = np.arange(2,10,1.5)

# %%
a5
# Out:
# array([2. , 3.5, 5. , 6.5, 8. , 9.5])

# %%
np.linspace(0,100,5)
# Out:
# array([  0.,  25.,  50.,  75., 100.])

# %%
np.linspace(0,10,5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
zero_a = np.zeros(3)

# %%
zero_a
# Out:
# array([0., 0., 0.])

# %%
zero_a2d = np.zeros((2,3))
zero_a2d
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
a1 = np.array([4,11,53,2,9])

# %%
print(a1.ndim)
# Out:
# 1

# %%
print(a1.shape)
# Out:
# (5,)

# %%
print(a1.dtype)
# Out:
# int64

# %%
print(a1[3])
# Out:
# 2

# %%
print(a1[:3])
# Out:
# [ 4 11 53]

# %%
print(a1[2:])
# Out:
# [53  2  9]

# %%
print(a1[2:5])
# Out:
# [53  2  9]

# %%
print(a1[-4:-1])
# Out:
# [11 53  2]

# %%
print(a1[(a1 > 5) & (a1 <= 11)])
# Out:
# [11  9]

# %%
a2 = np.arange(6).reshape(2,3)

# %%
a2.ndim
# Out:
# 2

# %%
a2.shape
# Out:
# (2, 3)

# %%
a2[1,2] #a2[1][2]
# Out:
# 5

# %%
a2
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
print(a2[0:1, 0:2])
# Out:
# [[0 1]]

# %%
print(a2[1:2, 0:2])
# Out:
# [[3 4]]

# %%
a1
# Out:
# array([ 4, 11, 53,  2,  9])

# %%
a1 = np.arange(4)

# %%
a1
# Out:
# array([0, 1, 2, 3])

# %%
a11 = a1*2
a11
# Out:
# array([0, 2, 4, 6])

# %%
a = np.array([1,2,3,4])
b = np.array([1,1,2,2])

# %%
a,b
# Out:
# (array([1, 2, 3, 4]), array([1, 1, 2, 2]))

# %%
a+b
# Out:
# array([2, 3, 5, 6])

# %%
a-b
# Out:
# array([0, 1, 1, 2])

# %%
a*b
# Out:
# array([1, 2, 6, 8])

# %%
a == b
# Out:
# array([ True, False, False, False])

# %%
np.array_equal(a,b)
# Out:
# False

# %%
a >= b
# Out:
# array([ True,  True,  True,  True])

# %%
mat1 = np.array([[2],
                 [1]])

# %%
mat2 = np.array([[2,4]])

# %%
mat1.shape
# Out:
# (2, 1)

# %%
mat2.shape
# Out:
# (1, 2)

# %%
np.matmul(mat1, mat2)
# Out:
# array([[4, 8],
#        [2, 4]])

# %%
mat1 @ mat2
# Out:
# array([[4, 8],
#        [2, 4]])

# %%
np.dot(mat1, mat2)
# Out:
# array([[4, 8],
#        [2, 4]])

# %%
a,b
# Out:
# (array([1, 2, 3, 4]), array([1, 1, 2, 2]))

# %%
np.dot(a,b)
# Out:
# 17

# %%
np.dot(2,3)
# Out:
# 6

# %%
a2
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
a2.ndim
# Out:
# 2

# %%
a2.shape
# Out:
# (2, 3)

# %%
np.sum(a2)
# Out:
# 15

# %%
np.sum(a2, axis = 0)
# Out:
# array([3, 5, 7])

# %%
np.sum(a2, axis = 1)
# Out:
# array([ 3, 12])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a , b
# Out:
# (array([1, 2, 3, 4]), array([1, 1, 2, 2]))

# %%
np.any(a <= b)
# Out:
# True

# %%
np.any(a > b)
# Out:
# True

# %%
np.all(a <= b)
# Out:
# False

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
np.where(a>2, 1, 0)
# Out:
# array([0, 0, 1, 1])

# %%
a3d = np.array([[[1,2]],
                [[5,6]]
                ])

# %%
a3d.ndim
# Out:
# 3

# %%
a3d.shape
# Out:
# (2, 1, 2)

# %%
a3d.reshape(2,2)
# Out:
# array([[1, 2],
#        [5, 6]])

# %%
a3d.reshape(2,-1)
# Out:
# array([[1, 2],
#        [5, 6]])

# %%
a3d.flatten()
# Out:
# array([1, 2, 5, 6])

# %%
a = np.arange(6).reshape(2,3)

# %%
a
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
a.T
# Out:
# array([[0, 3],
#        [1, 4],
#        [2, 5]])

# %%
a2
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
a1
# Out:
# array([0, 1, 2, 3])

# %%
a3 = np.array([4,2,7,5,1])

# %%
a3
# Out:
# array([4, 2, 7, 5, 1])

# %%
a3.sort()

# %%
a3
# Out:
# array([1, 2, 4, 5, 7])

# %%
a3 = np.array([4,2,7,5,1])

# %%
a3
# Out:
# array([4, 2, 7, 5, 1])

# %%
a4 = np.sort(a3)

# %%
a4
# Out:
# array([1, 2, 4, 5, 7])

# %%
a3
# Out:
# array([4, 2, 7, 5, 1])

# %%
np.argsort(a3)
# Out:
# array([4, 1, 0, 3, 2])

# %%
a1
# Out:
# array([0, 1, 2, 3])

# %%
np.split(a1, 2)
# Out:
# [array([0, 1]), array([2, 3])]

# %%
np.split(a1, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-1e5068b3f3be> in <module>
# ----> 1 np.split(a1, 3)
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in split(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/numpy/lib/shape_base.py in split(ary, indices_or_sections, axis)
#     870         N = ary.shape[axis]
#     871         if N % sections:
# --> 872             raise ValueError(
#     873                 'array split does not result in an equal division') from None
#     874     return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %%
c = np.array([3,6,1,7,5,2])

# %%
np.split(c, [1,3,5])

# %%
a2

# %%
print(np.hsplit(a2, [1,2]))

# %%
print(np.vsplit(a2, 2))

# %%
a1

# %%
np.vstack((a1, a1, a1))

# %%
b1 = a1.reshape(4,1)
b1

# %%
np.hstack((b1,b1,b1))

# %% [markdown]
# #### Case1:
# You are given two 2D array
#
# ```
# [[0,   0,  0],      [[0, 1, 2],
#  [10, 10, 10], and   [0, 1, 2],
#  [20, 20, 20],       [0, 1, 2],
#  [30, 30, 30]]       [0, 1, 2]]
#
# ```
# Shape of **first array** is **4x3**
#
# Shape of **second array** is **4x3**.
#
# Will addtion of these array be possible? Yes as the shape of these two array matches.

# %%
a = np.arange(0,40,10)

# %%
a

# %%
b = np.tile(a, (3,1))
b

# %%
c = np.tile(a, (4,2))
c

# %%
b

# %%
a = b.T

# %%
a

# %%
b = np.tile(np.arange(0,3), (4,1))

# %%
b

# %%
a + b

# %%
a #4,3

# %%
b = np.arange(0,3)

# %%
b

# %%
a+b

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = np.arange(0,40,10)
a

# %%
a = a.reshape(4,1)

# %%
a

# %%
b = np.arange(0,3)

# %%
b

# %%
a+b

# %% [markdown]
# The **smaller array is broadcast across the larger array** so that they have **compatible shapes**.
#
#
# #### Case 3:
#
# Imagine I have two array like this:
#
# ```
#      [[0],
#      [10],
#      [20],
#      [30]]
#
# ```
# and
#
# ```
#   [[0, 1, 2]]
#
# ```
#
# i.e. one column matrix and one row matrix.
#
# When we try to add these array up, broadcasting will replicate first array column wise 3 time and secord array row wise 4 times to match up the shape.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's learn about some **General Broadcasting Rules**
#
#     For each dimension ( going from right side)
#         1. The size of each dimension should be same OR
#         2. The size of one dimension should be 1
#
#
# ##### Rule 1 : If two array differ in the number of dimensions, the shape of one with fewer dimensions is padded with ones on its leading( Left Side).
#
# ##### Rule 2 : If the shape of two arrays doesnt match in any dimensions, the array with shape equal to 1 is stretched to match the other shape.
#
# ##### Rule 3 : If in any dimesion the sizes disagree and neither equal to 1 , then Error is raised.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
