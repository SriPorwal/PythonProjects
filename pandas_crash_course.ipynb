# %% [markdown]
# <a href="https://colab.research.google.com/github/SriPorwal/PythonProjects/blob/main/pandas_crash_course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Pandas Crash course!")
# Out:
# Welcome to Pandas Crash course!

# %% [markdown]
# #### Lets download and read the IMDB dataset to work with pandas
#
#   - File1: https://drive.google.com/file/d/1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd/view?usp=sharing
#   - File2: https://drive.google.com/file/d/1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm/view?usp=sharing

# %%
import numpy as np
import pandas as pd

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 76.8MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 83.9MB/s]

# %%
# !ls
# Out:
# directors.csv  movies.csv  sample_data

# %%
movies = pd.read_csv("movies.csv")

# %%
movies.head(10)
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
# 5           9  43606  250000000         155   873260194
# 6          10  43607  270000000          57   391081192
# 7          11  43608  200000000         107   586090727
# 8          12  43609  200000000         145  1065659812
# 9          13  43610  255000000          49    89289910
#
#                                         title  vote_average  vote_count  \
# 0                                      Avatar           7.2       11800
# 1    Pirates of the Caribbean: At World's End           6.9        4500
# 2                                     Spectre           6.3        4466
# ...

# %%
movies.shape
# Out:
# (1465, 12)

# %%
directors = pd.read_csv("directors.csv")

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
directors.shape
# Out:
# (2349, 4)

# %% [markdown]
# ### Approach 1: Row-oriented
#
#
# - It takes **2 arguments**
#     - A **list of rows**
#     - A **list of column names/labels**

# %%
pd.DataFrame([
    ["A", 30, "Mumbai"],
    ["B", 20, "Pune"],
    ["C", 40, "Hyderabad"]
],
columns = ["Name", "Age", "City"]
)
# Out:
#   Name  Age       City
# 0    A   30     Mumbai
# 1    B   20       Pune
# 2    C   40  Hyderabad

# %%
pd.DataFrame({"Name":["A", "B", "C"],
              "Age": [30,20,40],
              "City": ["Mumbai", "Pune", "Hyderabad"]})
# Out:
#   Name  Age       City
# 0    A   30     Mumbai
# 1    B   20       Pune
# 2    C   40  Hyderabad

# %%
dir_copy = pd.read_csv("directors.csv")
dir_copy.set_index('id', inplace = True)

# %%
dir_copy
# Out:
#       Unnamed: 0      director_name gender
# id
# 4762           0      James Cameron   Male
# 4763           1     Gore Verbinski   Male
# 4764           2         Sam Mendes   Male
# 4765           3  Christopher Nolan   Male
# 4766           4     Andrew Stanton   Male
# ...          ...                ...    ...
# 7106        2344      Shane Carruth   Male
# 7107        2345   Neill Dela Llana    NaN
# 7108        2346        Scott Smith    NaN
# 7109        2347        Daniel Hsia   Male
# 7110        2348   Brian Herzlinger   Male
#
# [2349 rows x 3 columns]

# %%
#1. Using iloc (implicit indexing)

# %%
dir_copy.iloc[1]
# Out:
# Unnamed: 0                    1
# director_name    Gore Verbinski
# gender                     Male
# Name: 4763, dtype: object

# %%
#2. loc (Explicit indexing)

# %%
dir_copy.loc[4763]
# Out:
# Unnamed: 0                    1
# director_name    Gore Verbinski
# gender                     Male
# Name: 4763, dtype: object

# %%
dir_copy.loc[4762:4764, 'director_name':'gender']
# Out:
#        director_name gender
# id
# 4762   James Cameron   Male
# 4763  Gore Verbinski   Male
# 4764      Sam Mendes   Male

# %%
dir_copy.iloc[1:3]
# Out:
#       Unnamed: 0   director_name gender
# id
# 4763           1  Gore Verbinski   Male
# 4764           2      Sam Mendes   Male

# %%
dir_copy["director_name"]
# Out:
# id
# 4762        James Cameron
# 4763       Gore Verbinski
# 4764           Sam Mendes
# 4765    Christopher Nolan
# 4766       Andrew Stanton
#               ...
# 7106        Shane Carruth
# 7107     Neill Dela Llana
# 7108          Scott Smith
# 7109          Daniel Hsia
# 7110     Brian Herzlinger
# Name: director_name, Length: 2349, dtype: object

# %%
#rename

# %%
dir_copy.rename({"gender":"Gender"}, axis = 1)
# Out:
#       Unnamed: 0      director_name Gender
# id
# 4762           0      James Cameron   Male
# 4763           1     Gore Verbinski   Male
# 4764           2         Sam Mendes   Male
# 4765           3  Christopher Nolan   Male
# 4766           4     Andrew Stanton   Male
# ...          ...                ...    ...
# 7106        2344      Shane Carruth   Male
# 7107        2345   Neill Dela Llana    NaN
# 7108        2346        Scott Smith    NaN
# 7109        2347        Daniel Hsia   Male
# 7110        2348   Brian Herzlinger   Male
#
# [2349 rows x 3 columns]

# %%
dir_copy.head()
# Out:
#       Unnamed: 0      director_name gender
# id
# 4762           0      James Cameron   Male
# 4763           1     Gore Verbinski   Male
# 4764           2         Sam Mendes   Male
# 4765           3  Christopher Nolan   Male
# 4766           4     Andrew Stanton   Male

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
movies.rename({"vote_average":"rating"}, axis = 1, inplace = True)

# %%
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  rating  vote_count  \
# 0                                       Avatar     7.2       11800
# 1     Pirates of the Caribbean: At World's End     6.9        4500
# ...

# %%
#add a row

# %%
dir_copy.loc[len(dir_copy.index)] = [2349, "Steven Spielberg", "M"]

# %%
dir_copy.tail(10)
# Out:
#       Unnamed: 0       director_name gender
# id
# 7102        2340    Kiyoshi Kurosawa   Male
# 7103        2341        Tadeo Garcia    NaN
# 7104        2342  Thomas L. Phillips    NaN
# 7105        2343     Ash Baron-Cohen    NaN
# 7106        2344       Shane Carruth   Male
# 7107        2345    Neill Dela Llana    NaN
# 7108        2346         Scott Smith    NaN
# 7109        2347         Daniel Hsia   Male
# 7110        2348    Brian Herzlinger   Male
# 2349        2349    Steven Spielberg      M

# %%
dir_copy.drop(2349, axis = 0).tail()
# Out:
#       Unnamed: 0     director_name gender
# id
# 7106        2344     Shane Carruth   Male
# 7107        2345  Neill Dela Llana    NaN
# 7108        2346       Scott Smith    NaN
# 7109        2347       Daniel Hsia   Male
# 7110        2348  Brian Herzlinger   Male

# %%
dir_copy.tail()
# Out:
#       Unnamed: 0     director_name gender
# id
# 7107        2345  Neill Dela Llana    NaN
# 7108        2346       Scott Smith    NaN
# 7109        2347       Daniel Hsia   Male
# 7110        2348  Brian Herzlinger   Male
# 2349        2349  Steven Spielberg      M

# %%
dir_copy.drop([7110,2349], axis = 0).tail()
# Out:
#       Unnamed: 0     director_name gender
# id
# 7105        2343   Ash Baron-Cohen    NaN
# 7106        2344     Shane Carruth   Male
# 7107        2345  Neill Dela Llana    NaN
# 7108        2346       Scott Smith    NaN
# 7109        2347       Daniel Hsia   Male

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
directors.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
#merging two dataframes

# %% [markdown]
# Since we need all the rows for movies, but not all of those for directors, to know the details of each movies, hence we will use left join.

# %%
data = movies.merge(directors, how = 'left', left_on = "director_id", right_on = "id")

# %%
data.head()
# Out:
#    Unnamed: 0   id_x     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  rating  vote_count  director_id  \
# 0                                    Avatar     7.2       11800         4762
# 1  Pirates of the Caribbean: At World's End     6.9        4500         4763
# 2                                   Spectre     6.3        4466         4764
# 3                     The Dark Knight Rises     7.6        9106         4765
# 4                              Spider-Man 3     5.9        3576         4767
#
#    year month       day      director_name  id_y gender
# 0  2009   Dec  Thursday      James Cameron  4762   Male
# ...

# %% [markdown]
# Notice, two stranger id columns `id_x` and `id_y`.
#
# #### What do you think these newly created cols are?
#
# Since the columns with name `id`is present in both the df
#
# - `id_x` represents **id values from movie df**
# - `id_y` represents **id values from directors df**
#
#
# We can simply drop these features

# %%
data.drop(['director_id','id_y'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    Unnamed: 0   id_x     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  rating  vote_count  year month  \
# 0                                    Avatar     7.2       11800  2009   Dec
# 1  Pirates of the Caribbean: At World's End     6.9        4500  2007   May
# 2                                   Spectre     6.3        4466  2015   Oct
# 3                     The Dark Knight Rises     7.6        9106  2012   Jul
# 4                              Spider-Man 3     5.9        3576  2007   May
#
#         day      director_name gender
# 0  Thursday      James Cameron   Male
# 1  Saturday     Gore Verbinski   Male
# 2    Monday         Sam Mendes   Male
# ...

# %%
#How to find sum of revenue and budget per movie?

# %%
data[['revenue','budget']].apply(np.sum)
#By default, axis = 0
# Out:
# revenue    209866997305
# budget      70353617179
# dtype: int64

# %%
data[['revenue','budget']].apply(np.sum, axis = 1)
# Out:
# 0       3024965087
# 1       1261000000
# 2       1125674609
# 3       1334939099
# 4       1148871626
#            ...
# 1460        321952
# 1461       3178130
# 1462             0
# 1463             0
# 1464       2260920
# Length: 1465, dtype: int64

# %% [markdown]
# #### What does this `axis` mean in apply ?
#   - If **axis = 0**, it will apply to **each column**, if **axis = 1**, **each row**
#   - By default axis = 0
#
# => `apply()` can be applied on any dataframe along any particular axis

# %%
#How can I find profit per movie? # revenue - budget?

# %%
def calc_profit(x):
  return x["revenue"] - x["budget"]

data["profit"] = data[["revenue", "budget"]].apply(calc_profit, axis = 1)

# %%
data.head()
# Out:
#    Unnamed: 0   id_x     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  rating  vote_count  year month  \
# 0                                    Avatar     7.2       11800  2009   Dec
# 1  Pirates of the Caribbean: At World's End     6.9        4500  2007   May
# 2                                   Spectre     6.3        4466  2015   Oct
# 3                     The Dark Knight Rises     7.6        9106  2012   Jul
# 4                              Spider-Man 3     5.9        3576  2007   May
#
#         day      director_name gender      profit
# 0  Thursday      James Cameron   Male  2550965087
# 1  Saturday     Gore Verbinski   Male   661000000
# ...

# %%
#Grouping

# %% [markdown]
# #### How can we know the number of movies released by a particular director, say, Christopher Nolan?

# %%
data.loc[data["director_name"] == "Christopher Nolan", ['title']].count()
# Out:
# title    8
# dtype: int64

# %%
data["director_name"].value_counts()
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %% [markdown]
# #### How can you find the average popularity of each director?
#
# We will have to some group our rows director wise.
#
#
# #### What is Grouping ?
#
# Simply it could be understood through the terms - Split, apply, combine

# %%
data.groupby("director_name")['title'].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
grouped_data = data.groupby("director_name")["title"].count()

# %%
grouped_data.head()
# Out:
# director_name
# Adam McKay                     6
# Adam Shankman                  8
# Alejandro González Iñárritu    6
# Alex Proyas                    5
# Alexander Payne                5
# Name: title, dtype: int64

# %%
grouped_data = data.groupby("director_name")["title"].count().reset_index()

# %%
grouped_data.head()
# Out:
#                  director_name  title
# 0                   Adam McKay      6
# 1                Adam Shankman      8
# 2  Alejandro González Iñárritu      6
# 3                  Alex Proyas      5
# 4              Alexander Payne      5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x = "director_name", y = "title", data=grouped_data)
# Out:
# <Axes: xlabel='director_name', ylabel='title'>

# %%
#plot this only for the first 5 directors

# %%
sns.barplot(x = "director_name", y = "title", data=grouped_data.head())
# Out:
# <Axes: xlabel='director_name', ylabel='title'>

# %%
sns.barplot(x = "director_name", y = "title", data=grouped_data.head(7))
# Out:
# <Axes: xlabel='director_name', ylabel='title'>

# %%
sns.barplot(x = "director_name", y = "title", data=grouped_data.head(7))
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Adam McKay'),
#   Text(1, 0, 'Adam Shankman'),
#   Text(2, 0, 'Alejandro González Iñárritu'),
#   Text(3, 0, 'Alex Proyas'),
#   Text(4, 0, 'Alexander Payne'),
#   Text(5, 0, 'Andrew Adamson'),
#   Text(6, 0, 'Andrew Niccol')])

# %% [markdown]
# #### How can we find multiple aggregations of any feature?

# %%
#Give me the first and the last year for each of the directors in which they have created a movie

# %%
data.groupby("director_name")["year"].aggregate(['min', 'max']) #groupby aggregation
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
#groupby filtering

# %% [markdown]
# #### How we find details of the movies by high budget directors?
#
#
# Lets assume,
# - high budget director -> any director with **atleast one movie with budget >100M**
#
#
# <!-- Notice, the question is **not asking us to give the name of the directors who have directed high budget movies**
#
# Lets first quickly see, how we would  have solved that
# To begin with,
#
# #### How can we find the names of high budget directors? -->

# %%
data.groupby("director_name").filter(lambda x: x["budget"].max() > 100000000)
# Out:
#       Unnamed: 0   id_x     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1450        4642  48267     400000          33   100000000
# 1451        4643  48268     200000          13     4505922
# 1452        4648  48274          0           5     2611555
# 1458        4708  48335      60000          27     3221152
# 1460        4736  48363          0           3      321952
#
#                                          title  rating  vote_count  year  \
# 0                                       Avatar     7.2       11800  2009
# 1     Pirates of the Caribbean: At World's End     6.9        4500  2007
# ...

# %% [markdown]
# Notice what's happening here?
# - We first group data by director and then use `groupby().filter` function
# - **Groups are filtered if they do not satisfy the boolean criterion** specified by function
# - This is called  **Group Based Filtering**

# %%
#Lets see the trend of avg rating of the directors across the years

# %%
top_data = data.groupby("director_name").filter(lambda x: x["budget"].max() > 100000000)

# %%
sns.lineplot(x= 'year', y='rating', data=top_data)
# Out:
# <Axes: xlabel='year', ylabel='rating'>

# %% [markdown]
# Now let's assume, we call a movie risky if,
# - its budget is higher than the average revenue of its director
#
# #### How do we filter risky movies?
#
# We can subtract the average `revenue` of a director from `budget` col, for each director
#
# #### Can we use `apply` here?
#
# Yes!
#
# #### How do we use apply for this column?
#
# - We will define a function to compute the subtraction
# - Pass this function in `apply`

# %%
def func(x):
  '''
  is_risky = False --> its NOT risky
  is_risky = True --> Its Risky
  '''
  x["is_risky"] = x["budget"] - x["revenue"].mean() >= 0
  return x

# %%
data_risky = data.groupby("director_name").apply(func)
data_risky.head()
# Out:
#    Unnamed: 0   id_x     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  rating  vote_count  year month  \
# 0                                    Avatar     7.2       11800  2009   Dec
# 1  Pirates of the Caribbean: At World's End     6.9        4500  2007   May
# 2                                   Spectre     6.3        4466  2015   Oct
# 3                     The Dark Knight Rises     7.6        9106  2012   Jul
# 4                              Spider-Man 3     5.9        3576  2007   May
#
#         day      director_name gender      profit  is_risky
# 0  Thursday      James Cameron   Male  2550965087     False
# ...

# %%
sns.countplot(x = data_risky['is_risky'])
# Out:
# <Axes: xlabel='is_risky', ylabel='count'>

# %%
data_risky.loc[data_risky["is_risky"]]
# Out:
#       Unnamed: 0   id_x     budget  popularity     revenue  \
# 7             11  43608  200000000         107   586090727
# 12            17  43614  380000000         135  1045713802
# 15            21  43618  200000000          37   310669540
# 20            27  43624  209000000          64   303025485
# 24            33  43630  210000000           3   459359555
# ...          ...    ...        ...         ...         ...
# 1347        3627  47224    5000000           7     3263585
# 1349        3632  47229    5000000           3     4842699
# 1351        3636  47233    5000000           6           0
# 1356        3665  47263   15000000          10           0
# 1383        3853  47453    3500000           4           0
#
#                                             title  rating  vote_count  year  \
# 7                               Quantum of Solace     6.1        2965  2008
# 12    Pirates of the Caribbean: On Stranger Tides     6.4        4948  2011
# ...

# %%
plt.figure(figsize = (15, 10))
sns.histplot(data['profit'], bins = 50)
# Out:
# <Axes: xlabel='profit', ylabel='Count'>

# %%
#Obs - majority of the movies lie in the 0-0.5M profit

# %% [markdown]
# Univariate
# 1. C - bargraph, countplot
# 2. N - Histogram, KDE, Boxplot
#
# Bi-variate
# 1. NN - Scatterplot, Lineplot
# 2. CC - Dodged Countplot, Stacked Count plot
# 3. NC - Dodged Boxplots, Barplot, KDE plots
